# %% [markdown]
# # AST research
#
# GPU JH has no general internet access. Download the AST snapshot on a machine with internet, sync it to `/opt/gen-content/margasanov/hf_models/ast-finetuned-audioset-10-10-0.4593`, then run training configs on JH.

# %%
from src.models.ast import build_ast
from src.models.resnet import count_parameters

model_path = '/opt/gen-content/margasanov/hf_models/ast-finetuned-audioset-10-10-0.4593'
model = build_ast(model_path, 4, False)
print(count_parameters(model))
